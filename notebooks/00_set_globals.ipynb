# %% [markdown]
# # Set globals
#
# This notebook sets the input data paths and a timestamp across notebooks.

# %%
from datetime import datetime
from pathlib import Path

TIMESTAMP = datetime.now().strftime("%Y-%m-%d")

SCRIPTS = Path("../scripts")
DATA = Path("../data")
assert DATA.exists() and DATA.is_dir(), "data/ has not been linked"
INTERMEDIATE = DATA / "intermediate/"
METADATA = DATA / "RNAquarium_moremetadata3b_fewercols2024-04-23.tab"
SEQTYPE_CALLS = DATA / "rnaquarium_seq_type_decisions_3.csv"
STATS_FILES = "stats-*.csv"

# %store TIMESTAMP SCRIPTS DATA INTERMEDIATE METADATA SEQTYPE_CALLS STATS_FILES
